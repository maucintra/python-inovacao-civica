# %% [markdown]
# # Escola de Dados - Python para inovação cívica
# ## Módulo 1: Por dentro do python
#
# - [Aula 5](#Aula-5:-Pacotes)
# - [Aula 6](#Aula-6:-Método-readcsv)
# - [Aula 7](#Aula-7:-Carregando-tabelas)
#
#
# ### Aula 5: Pacotes
#
# Instalaremos todos os pacotes que usaremos nesse módulo; Pandas, Matplotlib, Numpy, Jupiter Widgets e Pandas Profiling

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.3.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
#      |████████████████████████████████| 11.5 MB 4.7 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2021.1)
# Collecting numpy>=1.17.3
#   Downloading numpy-1.21.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 56.7 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Installing collected packages: numpy, pandas
# Successfully installed numpy-1.21.1 pandas-1.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.4.2-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 4.3 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (2.4.7)
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.3.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 59.6 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.16 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib) (1.21.1)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 58.4 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: six in /srv/conda/envs/notebook/lib/python3.7/site-packages (from cycler>=0.10->matplotlib) (1.15.0)
# Installing collected packages: pillow, kiwisolver, cycler, matplotlib
# Successfully installed cycler-0.10.0 kiwisolver-1.3.1 matplotlib-3.4.2 pillow-8.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in /srv/conda/envs/notebook/lib/python3.7/site-packages (1.21.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in /srv/conda/envs/notebook/lib/python3.7/site-packages (7.6.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipywidgets) (3.5.1)
# Requirement already satisfied: traitlets>=4.3.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipywidgets) (5.0.5)
# Requirement already satisfied: nbformat>=4.2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipywidgets) (5.1.2)
# Requirement already satisfied: ipython>=4.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipywidgets) (7.21.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipywidgets) (5.5.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipywidgets) (1.0.0)
# Requirement already satisfied: jupyter-client in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.11)
# Requirement already satisfied: tornado>=4.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: setuptools>=18.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (49.6.0.post20210108)
# Requirement already satisfied: backcall in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (0.18.0)
# Requirement already satisfied: pickleshare in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: pygments in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (2.8.0)
# Requirement already satisfied: pexpect>4.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (3.0.16)
# Requirement already satisfied: decorator in /srv/conda/envs/notebook/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets) (4.4.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.1)
# Requirement already satisfied: jupyter-core in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets) (4.7.1)
# Requirement already satisfied: ipython-genutils in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (0.17.3)
# Requirement already satisfied: six>=1.11.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (1.15.0)
# Requirement already satisfied: importlib-metadata in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (3.7.0)
# Requirement already satisfied: attrs>=17.4.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (20.3.0)
# Requirement already satisfied: ptyprocess>=0.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /srv/conda/envs/notebook/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.2.0)
# Requirement already satisfied: terminado>=0.8.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.9.2)
# Requirement already satisfied: argon2-cffi in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (20.1.0)
# Requirement already satisfied: nbconvert in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (6.0.7)
# Requirement already satisfied: jinja2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.11.3)
# Requirement already satisfied: Send2Trash>=1.5.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied: pyzmq>=17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (22.0.3)
# Requirement already satisfied: prometheus-client in /srv/conda/envs/notebook/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (2.8.1)
# Requirement already satisfied: cffi>=1.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.14.5)
# Requirement already satisfied: pycparser in /srv/conda/envs/notebook/lib/python3.7/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.20)
# Requirement already satisfied: typing-extensions>=3.6.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from importlib-metadata->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from importlib-metadata->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (3.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.1.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.4.2)
# Requirement already satisfied: jupyterlab-pygments in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: testpath in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.4.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.3)
# Requirement already satisfied: bleach in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.3.0)
# Requirement already satisfied: defusedxml in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.6.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.3)
# Requirement already satisfied: async-generator in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.10)
# Requirement already satisfied: nest-asyncio in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.4.3)
# Requirement already satisfied: webencodings in /srv/conda/envs/notebook/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Requirement already satisfied: packaging in /srv/conda/envs/notebook/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (20.9)
# Requirement already satisfied: pyparsing>=2.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.4.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.0.0-py2.py3-none-any.whl (248 kB)
#      |████████████████████████████████| 248 kB 4.6 MB/s eta 0:00:01
# Collecting visions[type_image_path]==0.7.1
#   Downloading visions-0.7.1-py3-none-any.whl (102 kB)
#      |████████████████████████████████| 102 kB 81.0 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.16.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas-profiling) (1.21.1)
# Collecting scipy>=1.4.1
#   Downloading scipy-1.7.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (28.5 MB)
#      |████████████████████████████████| 28.5 MB 75.9 MB/s eta 0:00:01
# Collecting joblib
#   Downloading joblib-1.0.1-py3-none-any.whl (303 kB)
#      |████████████████████████████████| 303 kB 59.0 MB/s eta 0:00:01
# Requirement already satisfied: matplotlib>=3.2.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas-profiling) (3.4.2)
# Collecting pydantic>=1.8.1
#   Downloading pydantic-1.8.2-cp37-cp37m-manylinux2014_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 46.7 MB/s eta 0:00:01
# Requirement already satisfied: jinja2>=2.11.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas-profiling) (2.11.3)
# Collecting htmlmin>=0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
# Collecting missingno>=0.4.2
#   Downloading missingno-0.5.0-py3-none-any.whl (8.8 kB)
# Collecting phik>=0.11.1
#   Downloading phik-0.12.0-cp37-cp37m-manylinux2010_x86_64.whl (675 kB)
#      |████████████████████████████████| 675 kB 47.5 MB/s eta 0:00:01
# Collecting tangled-up-in-unicode==0.1.0
#   Downloading tangled_up_in_unicode-0.1.0-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 35.2 MB/s eta 0:00:01
# Collecting tqdm>=4.48.2
#   Downloading tqdm-4.62.0-py2.py3-none-any.whl (76 kB)
#      |████████████████████████████████| 76 kB 7.0 MB/s  eta 0:00:01
# Collecting seaborn>=0.10.1
#   Downloading seaborn-0.11.1-py3-none-any.whl (285 kB)
#      |████████████████████████████████| 285 kB 62.7 MB/s eta 0:00:01
# Collecting PyYAML>=5.0.0
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 48.3 MB/s eta 0:00:01
# Requirement already satisfied: requests>=2.24.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas-profiling) (2.25.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas-profiling) (1.3.1)
# Requirement already satisfied: attrs>=19.3.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from visions[type_image_path]==0.7.1->pandas-profiling) (20.3.0)
# Collecting multimethod==1.4
#   Downloading multimethod-1.4-py2.py3-none-any.whl (7.3 kB)
# Collecting networkx>=2.4
#   Downloading networkx-2.6.2-py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 58.6 MB/s eta 0:00:01
# Collecting bottleneck
#   Downloading Bottleneck-1.3.2.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 9.7 MB/s  eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting imagehash
#   Downloading ImageHash-4.2.1.tar.gz (812 kB)
#      |████████████████████████████████| 812 kB 52.4 MB/s eta 0:00:01
# Requirement already satisfied: Pillow in /srv/conda/envs/notebook/lib/python3.7/site-packages (from visions[type_image_path]==0.7.1->pandas-profiling) (8.3.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jinja2>=2.11.1->pandas-profiling) (1.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.8.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.10.0)
# Requirement already satisfied: six in /srv/conda/envs/notebook/lib/python3.7/site-packages (from cycler>=0.10->matplotlib>=3.2.0->pandas-profiling) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2021.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pydantic>=1.8.1->pandas-profiling) (3.7.4.3)
# Requirement already satisfied: idna<3,>=2.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.24.0->pandas-profiling) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.24.0->pandas-profiling) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.24.0->pandas-profiling) (1.26.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.24.0->pandas-profiling) (4.0.0)
# Collecting PyWavelets
#   Downloading PyWavelets-1.1.1-cp37-cp37m-manylinux1_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 52.2 MB/s eta 0:00:01
# Building wheels for collected packages: htmlmin, bottleneck, imagehash
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27085 sha256=d4df7d4ccc6668ddd9dc6195c1f0abc113841e38583856a26bc3c70421ddfaf6
#   Stored in directory: /home/jovyan/.cache/pip/wheels/70/e1/52/5b14d250ba868768823940c3229e9950d201a26d0bd3ee8655
#   Building wheel for bottleneck (PEP 517) ... done
#   Created wheel for bottleneck: filename=Bottleneck-1.3.2-cp37-cp37m-linux_x86_64.whl size=335074 sha256=becc3127b3243a368cd47083d73ec07fa656f477669e87e6640e9defc98c8121
#   Stored in directory: /home/jovyan/.cache/pip/wheels/87/85/9c/a325c89ff0498660ef8a335fb4b3912939c273ea4f094af29f
#   Building wheel for imagehash (setup.py) ... done
#   Created wheel for imagehash: filename=ImageHash-4.2.1-py2.py3-none-any.whl size=295198 sha256=45e63ea6171ca9dfe1222fff1de8c5d34045a42ce6ff8897962c7347f0fcfd1a
#   Stored in directory: /home/jovyan/.cache/pip/wheels/4c/d5/59/5e3e297533ddb09407769762985d134135064c6831e29a914e
# Successfully built htmlmin bottleneck imagehash
# Installing collected packages: tangled-up-in-unicode, scipy, PyWavelets, networkx, multimethod, bottleneck, visions, seaborn, joblib, imagehash, tqdm, PyYAML, pydantic, phik, missingno, htmlmin, pandas-profiling
# Successfully installed PyWavelets-1.1.1 PyYAML-5.4.1 bottleneck-1.3.2 htmlmin-0.1.12 imagehash-4.2.1 joblib-1.0.1 missingno-0.5.0 multimethod-1.4 networkx-2.6.2 pandas-profiling-3.0.0 phik-0.12.0 pydantic-1.8.2 scipy-1.7.1 seaborn-0.11.1 tangled-up-in-unicode-0.1.0 tqdm-4.62.0 visions-0.7.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# A instalação é só realizada 1 vez, mas a importação das bibliotecas deve ocorrer no inicío do código, como na próxima linha:

# %%
import pandas as pd

# %% [markdown]
# ### Aula 6: Método readcsv
# Vamos aprender a ler arquivos do tipo CSV e converter para dataframe Pandas.
#
# Os dados que usaremos nesse notebook pode ser encontrado em: [TSE. Candidaturas em 2020](https://www.tse.jus.br/eleicoes/estatisticas/repositorio-de-dados-eleitorais-1)

# %%
candidaturas_pe = pd.read_csv('./base_dados/consulta_cand_2020_PE.csv', sep=';', encoding='latin_1')

# %%
# o comando abaixo retira a limitação da quantidade de colunas impressa na tela

pd.options.display.max_columns = None

# %%
candidaturas_pe.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 1  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 2  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 3  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 4  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
#
#    NR_TURNO  CD_ELEICAO                DS_ELEICAO  DT_ELEICAO TP_ABRANGENCIA  \
# 0         1         426  Eleições Municipais 2020  15/11/2020      MUNICIPAL
# 1         1         426  Eleições Municipais 2020  15/11/2020      MUNICIPAL
# 2         1         426  Eleições Municipais 2020  15/11/2020      MUNICIPAL
# 3         1         426  Eleições Municipais 2020  15/11/2020      MUNICIPAL
# 4         1         426  Eleições Municipais 2020  15/11/2020      MUNICIPAL
#
#   SG_UF  SG_UE        NM_UE  CD_CARGO  DS_CARGO  SQ_CANDIDATO  NR_CANDIDATO  \
# 0    PE  23817      CARUARU        13  VEREADOR  170001231149         17008
# 1    PE  23094  ÁGUAS BELAS        13  VEREADOR  170000800795         15515
# 2    PE  25313       RECIFE        13  VEREADOR  170000836659         25033
# 3    PE  24970     OURICURI        13  VEREADOR  170000648896         45777
# 4    PE  24996     PALMARES        13  VEREADOR  170001129430         90090
#
#                         NM_CANDIDATO         NM_URNA_CANDIDATO  \
# 0    MARIA DE LOURDES ALVES DE SOUZA   DONA LOURDES DA BONANÇA
# 1  JOSÉ MAREVALDO BARROS DE OLIVEIRA       MAREVALDO DA RUA 15
# 2            JOSÉ AGNIS PERKLES RÊGO                JOSÉ AGNIS
# 3               DELVANI SILVA SOBRAL           DELVANIA SOBRAL
# 4       MARILENE SHEILLA DE OLIVEIRA  SHEILLA DO MEIO AMBIENTE
#
#   NM_SOCIAL_CANDIDATO  NR_CPF_CANDIDATO                     NM_EMAIL  \
# 0              #NULO#       12310328472   NG_CONSULTORIA@HOTMAIL.COM
# 1              #NULO#       59971576449  MDBABCAMPANHA2020@GMAIL.COM
# 2              #NULO#       61079570730  DIRETORIODEMREC25@GMAIL.COM
# 3              #NULO#       68068123415  DELVANIA_SOBRAL@HOTMAIL.COM
# 4              #NULO#        4522160445      MARC_GUEDES@HOTMAIL.COM
#
#    CD_SITUACAO_CANDIDATURA DS_SITUACAO_CANDIDATURA  CD_DETALHE_SITUACAO_CAND  \
# 0                       12                    APTO                         2
# 1                       12                    APTO                         2
# 2                       12                    APTO                         2
# 3                       12                    APTO                         2
# 4                        3                  INAPTO                         6
#
#   DS_DETALHE_SITUACAO_CAND    TP_AGREMIACAO  NR_PARTIDO SG_PARTIDO  \
# 0                 DEFERIDO  PARTIDO ISOLADO          17        PSL
# 1                 DEFERIDO  PARTIDO ISOLADO          15        MDB
# 2                 DEFERIDO  PARTIDO ISOLADO          25        DEM
# 3                 DEFERIDO  PARTIDO ISOLADO          45       PSDB
# 4                 RENÚNCIA  PARTIDO ISOLADO          90       PROS
#
#                                 NM_PARTIDO  SQ_COLIGACAO     NM_COLIGACAO  \
# 0                   PARTIDO SOCIAL LIBERAL  170000152093  PARTIDO ISOLADO
# 1         MOVIMENTO DEMOCRÁTICO BRASILEIRO  170000078841  PARTIDO ISOLADO
# 2                               DEMOCRATAS  170000088761  PARTIDO ISOLADO
# 3  PARTIDO DA SOCIAL DEMOCRACIA BRASILEIRA  170000057628  PARTIDO ISOLADO
# 4      PARTIDO REPUBLICANO DA ORDEM SOCIAL  170000136900  PARTIDO ISOLADO
#
#   DS_COMPOSICAO_COLIGACAO  CD_NACIONALIDADE           DS_NACIONALIDADE  \
# 0                     PSL                 1            BRASILEIRA NATA
# 1                     MDB                 1            BRASILEIRA NATA
# 2                     DEM                 1            BRASILEIRA NATA
# 3                    PSDB                 2  BRASILEIRA (NATURALIZADA)
# 4                    PROS                 1            BRASILEIRA NATA
#
#   SG_UF_NASCIMENTO  CD_MUNICIPIO_NASCIMENTO NM_MUNICIPIO_NASCIMENTO  \
# 0               PE                       -3                  RECIFE
# 1               PE                       -3             ÁGUAS BELAS
# 2               RJ                       -3          RIO DE JANEIRO
# 3               PE                       -3                OURICURI
# 4               AL                       -3                  MACEIÓ
#
#   DT_NASCIMENTO  NR_IDADE_DATA_POSSE  NR_TITULO_ELEITORAL_CANDIDATO  \
# 0    09/10/1952                   68                     3341960884
# 1    28/09/1969                   51                    34158500825
# 2    27/05/1962                   58                    73197820337
# 3    10/03/1971                   49                    40086930833
# 4    26/07/1973                   47                    54096200809
#
#    CD_GENERO  DS_GENERO  CD_GRAU_INSTRUCAO              DS_GRAU_INSTRUCAO  \
# 0          4   FEMININO                  6          ENSINO MÉDIO COMPLETO
# 1          2  MASCULINO                  3  ENSINO FUNDAMENTAL INCOMPLETO
# 2          2  MASCULINO                  8              SUPERIOR COMPLETO
# 3          4   FEMININO                  8              SUPERIOR COMPLETO
# 4          4   FEMININO                  8              SUPERIOR COMPLETO
#
#    CD_ESTADO_CIVIL DS_ESTADO_CIVIL  CD_COR_RACA DS_COR_RACA  CD_OCUPACAO  \
# 0                3       CASADO(A)            3       PARDA          999
# 1                3       CASADO(A)            3       PARDA          999
# 2                9   DIVORCIADO(A)            1      BRANCA          131
# 3                1     SOLTEIRO(A)            3       PARDA          298
# 4                1     SOLTEIRO(A)            3       PARDA          999
#
#                   DS_OCUPACAO  VR_DESPESA_MAX_CAMPANHA  CD_SIT_TOT_TURNO  \
# 0                      OUTROS                149376.80                 5
# 1                      OUTROS                 48405.01                 5
# 2                    ADVOGADO               1011149.65                 5
# 3  SERVIDOR PÚBLICO MUNICIPAL                 26120.37                 2
# 4                      OUTROS                 26666.50                -1
#
#   DS_SIT_TOT_TURNO ST_REELEICAO ST_DECLARAR_BENS  NR_PROTOCOLO_CANDIDATURA  \
# 0         SUPLENTE            N                N                        -1
# 1         SUPLENTE            N                S                        -1
# 2         SUPLENTE            N                S                        -1
# 3    ELEITO POR QP            N                S                        -1
# 4           #NULO#            N                S                        -1
#
#            NR_PROCESSO  CD_SITUACAO_CANDIDATO_PLEITO  \
# 0  6004724720206170105                             2
# 1  6000665220206170064                             2
# 2  6001433520206170008                             2
# 3  6001353020206170082                             2
# 4  6002360820206170037                            -1
#
#   DS_SITUACAO_CANDIDATO_PLEITO  CD_SITUACAO_CANDIDATO_URNA  \
# 0                     DEFERIDO                           2
# 1                     DEFERIDO                           2
# 2                     DEFERIDO                           2
# 3                     DEFERIDO                           2
# 4                       #NULO#                          -1
#
#   DS_SITUACAO_CANDIDATO_URNA ST_CANDIDATO_INSERIDO_URNA
# 0                   DEFERIDO                        SIM
# 1                   DEFERIDO                        SIM
# 2                   DEFERIDO                        SIM
# 3                   DEFERIDO                        SIM
# 4                     #NULO#                        NÃO

# %%
# informação sobre o tamanho do dataframe (qnt. linhas, qnt. colunas)
candidaturas_pe.shape
# Out:
# (21101, 63)

# %% [markdown]
# ## Quantas candidaturas houveram no seu município nas eleições de 2020?

# %%
candidates_buique = candidaturas_pe.loc[candidaturas_pe['NM_UE'] == 'BUÍQUE']

candidates_buique.head()
# Out:
#       DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 38    05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 50    05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 660   05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 744   05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
# 1119  05/08/2021   12:18:13         2020                2  ELEIÇÃO ORDINÁRIA
#
#       NR_TURNO  CD_ELEICAO                DS_ELEICAO  DT_ELEICAO  \
# 38           1         426  Eleições Municipais 2020  15/11/2020
# 50           1         426  Eleições Municipais 2020  15/11/2020
# 660          1         426  Eleições Municipais 2020  15/11/2020
# 744          1         426  Eleições Municipais 2020  15/11/2020
# 1119         1         426  Eleições Municipais 2020  15/11/2020
#
#      TP_ABRANGENCIA SG_UF  SG_UE   NM_UE  CD_CARGO  DS_CARGO  SQ_CANDIDATO  \
# 38        MUNICIPAL    PE  23558  BUÍQUE        13  VEREADOR  170000761464
# 50        MUNICIPAL    PE  23558  BUÍQUE        13  VEREADOR  170000763863
# 660       MUNICIPAL    PE  23558  BUÍQUE        13  VEREADOR  170000763496
# 744       MUNICIPAL    PE  23558  BUÍQUE        13  VEREADOR  170000763856
# 1119      MUNICIPAL    PE  23558  BUÍQUE        13  VEREADOR  170000763506
#
#       NR_CANDIDATO                              NM_CANDIDATO  \
# 38           15888                      JOSÉ ADÃO DOS SANTOS
# 50           77333                     AUDÁLIO JOSÉ DA SILVA
# 660          55960  VALMIRA DE SIQUEIRA LEAL DE SOUZA AMORIM
# 744          77788                     ANA MARIA ACIOLE NETO
# 1119         55000             NERICLESIO OLÍMPIO DOS SANTOS
#
#       NM_URNA_CANDIDATO NM_SOCIAL_CANDIDATO  NR_CPF_CANDIDATO  \
# 38          DÃO TAVARES              #NULO#       22684131449
# 50      ODÁLIO DA SERRA              #NULO#       94661650468
# 660   VAMIRA DE EDNALDO              #NULO#        3802405480
# 744          ANA DO BAR              #NULO#       98443739487
# 1119        NERI SANTOS              #NULO#       11477641408
#
#                           NM_EMAIL  CD_SITUACAO_CANDIDATURA  \
# 38           MDBBUIQUE15@GMAIL.COM                       12
# 50        ADV.ALVESROCHA@GMAIL.COM                       12
# 660   ADV.CARLOSHALMEIDA@GMAIL.COM                       12
# 744       ADV.ALVESROCHA@GMAIL.COM                       12
# 1119  ADV.CARLOSHALMEIDA@GMAIL.COM                       12
#
#      DS_SITUACAO_CANDIDATURA  CD_DETALHE_SITUACAO_CAND  \
# 38                      APTO                         2
# 50                      APTO                         2
# 660                     APTO                         2
# 744                     APTO                         2
# 1119                    APTO                         2
#
#      DS_DETALHE_SITUACAO_CAND    TP_AGREMIACAO  NR_PARTIDO     SG_PARTIDO  \
# 38                   DEFERIDO  PARTIDO ISOLADO          15            MDB
# 50                   DEFERIDO  PARTIDO ISOLADO          77  SOLIDARIEDADE
# 660                  DEFERIDO  PARTIDO ISOLADO          55            PSD
# 744                  DEFERIDO  PARTIDO ISOLADO          77  SOLIDARIEDADE
# 1119                 DEFERIDO  PARTIDO ISOLADO          55            PSD
#
#                             NM_PARTIDO  SQ_COLIGACAO     NM_COLIGACAO  \
# 38    MOVIMENTO DEMOCRÁTICO BRASILEIRO  170000073229  PARTIDO ISOLADO
# 50                       SOLIDARIEDADE  170000073563  PARTIDO ISOLADO
# 660         PARTIDO SOCIAL DEMOCRÁTICO  170000073504  PARTIDO ISOLADO
# 744                      SOLIDARIEDADE  170000073563  PARTIDO ISOLADO
# 1119        PARTIDO SOCIAL DEMOCRÁTICO  170000073504  PARTIDO ISOLADO
#
#      DS_COMPOSICAO_COLIGACAO  CD_NACIONALIDADE DS_NACIONALIDADE  \
# 38                       MDB                 1  BRASILEIRA NATA
# 50             SOLIDARIEDADE                 1  BRASILEIRA NATA
# 660                      PSD                 1  BRASILEIRA NATA
# 744            SOLIDARIEDADE                 1  BRASILEIRA NATA
# 1119                     PSD                 1  BRASILEIRA NATA
#
#      SG_UF_NASCIMENTO  CD_MUNICIPIO_NASCIMENTO NM_MUNICIPIO_NASCIMENTO  \
# 38                 PE                       -3                  BUÍQUE
# 50                 PE                       -3                  BUÍQUE
# 660                PE                       -3                  BUÍQUE
# 744                SP                       -3               SÃO PAULO
# 1119               PE                       -3                  MANARI
#
#      DT_NASCIMENTO  NR_IDADE_DATA_POSSE  NR_TITULO_ELEITORAL_CANDIDATO  \
# 38      21/04/1960                   60                    17959160809
# 50      13/06/1975                   45                    44880640825
# 660     01/09/1974                   46                    41811000833
# 744     21/07/1971                   49                    36691360841
# 1119    05/01/1996                   24                    92611370809
#
#       CD_GENERO  DS_GENERO  CD_GRAU_INSTRUCAO              DS_GRAU_INSTRUCAO  \
# 38            2  MASCULINO                  4    ENSINO FUNDAMENTAL COMPLETO
# 50            2  MASCULINO                  3  ENSINO FUNDAMENTAL INCOMPLETO
# 660           4   FEMININO                  8              SUPERIOR COMPLETO
# 744           4   FEMININO                  6          ENSINO MÉDIO COMPLETO
# 1119          2  MASCULINO                  6          ENSINO MÉDIO COMPLETO
#
#       CD_ESTADO_CIVIL DS_ESTADO_CIVIL  CD_COR_RACA DS_COR_RACA  CD_OCUPACAO  \
# 38                  3       CASADO(A)            3       PARDA          278
# 50                  3       CASADO(A)            3       PARDA          601
# 660                 3       CASADO(A)            1      BRANCA          601
# 744                 9   DIVORCIADO(A)            3       PARDA          169
# 1119                1     SOLTEIRO(A)            1      BRANCA          931
#
#                                          DS_OCUPACAO  VR_DESPESA_MAX_CAMPANHA  \
# 38                                          VEREADOR                 17066.56
# 50                                        AGRICULTOR                 17066.56
# 660                                       AGRICULTOR                 17066.56
# 744                                      COMERCIANTE                 17066.56
# 1119  ESTUDANTE, BOLSISTA, ESTAGIÁRIO E ASSEMELHADOS                 17066.56
#
#       CD_SIT_TOT_TURNO DS_SIT_TOT_TURNO ST_REELEICAO ST_DECLARAR_BENS  \
# 38                   5         SUPLENTE            N                S
# 50                   5         SUPLENTE            N                S
# 660                  5         SUPLENTE            N                S
# 744                  5         SUPLENTE            N                S
# 1119                 5         SUPLENTE            N                S
#
#       NR_PROTOCOLO_CANDIDATURA          NR_PROCESSO  \
# 38                          -1  6000700420206170060
# 50                          -1  6001177520206170060
# 660                         -1  6001133820206170060
# 744                         -1  6001142320206170060
# 1119                        -1  6001081620206170060
#
#       CD_SITUACAO_CANDIDATO_PLEITO DS_SITUACAO_CANDIDATO_PLEITO  \
# 38                               2                     DEFERIDO
# 50                               2                     DEFERIDO
# 660                              2                     DEFERIDO
# 744                              2                     DEFERIDO
# 1119                             2                     DEFERIDO
#
#       CD_SITUACAO_CANDIDATO_URNA DS_SITUACAO_CANDIDATO_URNA  \
# 38                             2                   DEFERIDO
# 50                             2                   DEFERIDO
# 660                            2                   DEFERIDO
# 744                            2                   DEFERIDO
# 1119                           2                   DEFERIDO
#
#      ST_CANDIDATO_INSERIDO_URNA
# 38                          SIM
# 50                          SIM
# 660                         SIM
# 744                         SIM
# 1119                        SIM

# %%
candidates_buique.shape
# Out:
# (80, 63)

# %% [markdown]
# ## Aula 7: Carregando tabelas
#
# É possível ler vários arquivos CSV e converter de uma só vez para dataframe Pandas. Para isso, além de usar as técnicas vistas nas aulas anteriores, importaremos a biblioteca glob.

# %%
import glob

# %%
dados_todos_estados = glob.glob('../base_dados/consulta_*.csv')
print(dados_todos_estados)
# Out:
# ['../conjunto_dados/consulta_cand_2020_PI.csv', '../conjunto_dados/consulta_cand_2020_MT.csv', '../conjunto_dados/consulta_cand_2020_PB.csv', '../conjunto_dados/consulta_cand_2020_PA.csv', '../conjunto_dados/consulta_cand_2020_SP.csv', '../conjunto_dados/consulta_cand_2020_AL.csv', '../conjunto_dados/consulta_cand_2020_PE.csv', '../conjunto_dados/consulta_cand_2020_RR.csv', '../conjunto_dados/consulta_cand_2020_MS.csv', '../conjunto_dados/consulta_cand_2020_AP.csv', '../conjunto_dados/consulta_cand_2020_MG.csv', '../conjunto_dados/consulta_cand_2020_PR.csv', '../conjunto_dados/consulta_cand_2020_ES.csv', '../conjunto_dados/consulta_cand_2020_RJ.csv', '../conjunto_dados/consulta_cand_2020_MA.csv', '../conjunto_dados/consulta_cand_2020_AC.csv', '../conjunto_dados/consulta_cand_2020_RN.csv', '../conjunto_dados/consulta_cand_2020_CE.csv', '../conjunto_dados/consulta_cand_2020_RS.csv', '../conjunto_dados/consulta_cand_2020_SE.csv', '../conjunto_dados/consulta_cand_2020_GO.csv', '../conjunto_dados/consulta_cand_2020_BA.csv', '../conjunto_dados/consulta_cand_2020_AM.csv', '../conjunto_dados/consulta_cand_2020_TO.csv', '../conjunto_dados/consulta_cand_2020_SC.csv', '../conjunto_dados/consulta_cand_2020_RO.csv']

# %% [markdown]
# Vamos ler todos os arquivos e reunir em uma lista.

# %%
lista_df = []

for dados_estado in dados_todos_estados:
    df_estado = pd.read_csv(dados_estado, sep=';', encoding='latin_1')
    lista_df.append(df_estado)

# %% [markdown]
# Com o método `pd.concat` poderemos reunir os dataframes de cada estado em um único

# %%
df_completo = pd.concat(lista_df, axis=0, ignore_index=True)
df_completo.shape
# Out:
# (557842, 63)
